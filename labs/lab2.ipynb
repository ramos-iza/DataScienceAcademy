# %% [markdown]
# ## Laboratório Prático - Label Encoding

# %%
# Imports
import pandas as pd
import datetime

# %%
# Extrai a data atual do sistema
data_atual = datetime.datetime.now()

# %%
data_atual
# Out:
# datetime.datetime(2023, 8, 3, 19, 32, 54, 782388)

# %%
# Vamos gerar um range de datas dos 20 anteriores à data atual
date_list = [data_atual - datetime.timedelta(days = x) for x in range(0,20) ]

# %%
date_list
# Out:
# [datetime.datetime(2023, 8, 3, 19, 32, 54, 782388),
#  datetime.datetime(2023, 8, 2, 19, 32, 54, 782388),
#  datetime.datetime(2023, 8, 1, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 31, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 30, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 29, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 28, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 27, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 26, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 25, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 24, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 23, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 22, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 21, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 20, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 19, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 18, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 17, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 16, 19, 32, 54, 782388),
#  datetime.datetime(2023, 7, 15, 19, 32, 54, 782388)]

# %%
# Convertemos a lista em um dataframe
df = pd.DataFrame(date_list)

# %%
df.head()
# Out:
#                            0
# 0 2023-08-03 19:32:54.782388
# 1 2023-08-02 19:32:54.782388
# 2 2023-08-01 19:32:54.782388
# 3 2023-07-31 19:32:54.782388
# 4 2023-07-30 19:32:54.782388

# %%
# Ajusta o nome da coluna
df.columns = ['data']

# %%
df.head()
# Out:
#                         data
# 0 2023-08-03 19:32:54.782388
# 1 2023-08-02 19:32:54.782388
# 2 2023-08-01 19:32:54.782388
# 3 2023-07-31 19:32:54.782388
# 4 2023-07-30 19:32:54.782388

# %%
# Extraímos os dias da semana
df['dia_da_semana'] = df['data'].dt.day_name()

# %%
df
# Out:
#                          data dia_da_semana
# 0  2023-08-03 19:32:54.782388      Thursday
# 1  2023-08-02 19:32:54.782388     Wednesday
# 2  2023-08-01 19:32:54.782388       Tuesday
# 3  2023-07-31 19:32:54.782388        Monday
# 4  2023-07-30 19:32:54.782388        Sunday
# 5  2023-07-29 19:32:54.782388      Saturday
# 6  2023-07-28 19:32:54.782388        Friday
# 7  2023-07-27 19:32:54.782388      Thursday
# 8  2023-07-26 19:32:54.782388     Wednesday
# 9  2023-07-25 19:32:54.782388       Tuesday
# 10 2023-07-24 19:32:54.782388        Monday
# 11 2023-07-23 19:32:54.782388        Sunday
# 12 2023-07-22 19:32:54.782388      Saturday
# 13 2023-07-21 19:32:54.782388        Friday
# 14 2023-07-20 19:32:54.782388      Thursday
# 15 2023-07-19 19:32:54.782388     Wednesday
# 16 2023-07-18 19:32:54.782388       Tuesday
# 17 2023-07-17 19:32:54.782388        Monday
# 18 2023-07-16 19:32:54.782388        Sunday
# 19 2023-07-15 19:32:54.782388      Saturday

# %%
# Criamos um dicionário mapeando dia da semana com um número correspondente
# Obs: se o seu sistema estiver em português e se for necessário, use os dias da semana em português
dict_dia_semana = {'Monday':1, 
                   "Tuesday":2,
                   "Wednesday":3,
                   "Thursday":4,
                   "Friday":5,
                   "Saturday":6,
                   "Sunday":7}

# %%
# Label Encode - Substituímos o nome da semana pelo número correspondente
df['dia_semana_cod'] = df['dia_da_semana'].map(dict_dia_semana)

# %%
df
# Out:
#                          data dia_da_semana  dia_semana_cod
# 0  2023-08-03 19:32:54.782388      Thursday               4
# 1  2023-08-02 19:32:54.782388     Wednesday               3
# 2  2023-08-01 19:32:54.782388       Tuesday               2
# 3  2023-07-31 19:32:54.782388        Monday               1
# 4  2023-07-30 19:32:54.782388        Sunday               7
# 5  2023-07-29 19:32:54.782388      Saturday               6
# 6  2023-07-28 19:32:54.782388        Friday               5
# 7  2023-07-27 19:32:54.782388      Thursday               4
# 8  2023-07-26 19:32:54.782388     Wednesday               3
# 9  2023-07-25 19:32:54.782388       Tuesday               2
# 10 2023-07-24 19:32:54.782388        Monday               1
# 11 2023-07-23 19:32:54.782388        Sunday               7
# 12 2023-07-22 19:32:54.782388      Saturday               6
# 13 2023-07-21 19:32:54.782388        Friday               5
# 14 2023-07-20 19:32:54.782388      Thursday               4
# 15 2023-07-19 19:32:54.782388     Wednesday               3
# 16 2023-07-18 19:32:54.782388       Tuesday               2
# 17 2023-07-17 19:32:54.782388        Monday               1
# 18 2023-07-16 19:32:54.782388        Sunday               7
# 19 2023-07-15 19:32:54.782388      Saturday               6
