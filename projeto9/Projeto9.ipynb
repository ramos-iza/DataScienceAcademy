# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Análise de Dados com Linguagem Python</font>
#
# ## <font color='blue'>Projeto 9</font>
# ## <font color='blue'>Pré-Processamento de Dados de Texto Extraídos de Data Lake</font>

# %%
#!pip install -q pymongo

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.8.17

# %%
# Imports
import json
import pymongo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import pymongo

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# json      : 2.0.9
# numpy     : 1.24.4
# seaborn   : 0.11.1
# pymongo   : 4.0.1
# pandas    : 1.3.3
# matplotlib: 3.4.3

# %%
# Abre a conexão
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# Cria um repositório (banco de dados) chamado datalake
datalake = client["datalake"]

# %%
datalake
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'datalake')

# %%
# Se existir, deleta a coleção chamada posts
datalake.posts.drop()

# %%
# Cria a coleção chamada posts
posts = datalake["posts"]

# %% [markdown]
# ## Carregando Dados no Data Lake

# %%
#o mongo db precisa estar rodando na sua máquina loca
# terinal > ./mongob -- dbpath .

# %%
# Carrega o arquivo json em uma variável Python
with open('dados/dataset.json') as file:
    file_data = json.load(file)

# %%
file_data
# Out:
# [{'status': 'public',
#   'creationDate': '2017-07-17T20:05:49Z',
#   'allowComments': True,
#   'title': 'ligula nec sem duis aliquam',
#   'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#   'tags': 1,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2019-01-19T15:45:57Z',
#   'allowComments': False,
#   'title': 'mus vivamus vestibulum sagittis sapien cum',
#   'description': 'nec nisi volutpat eleifend donec ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus',
#   'tags': 0,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2019-03-22T17:18:15Z',
#   'allowComments': True,
#   'title': 'vel nulla eget eros elementum',
#   'description': 'quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti cras in purus eu magna vulputate luctus cum sociis',
#   'tags': 6,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2019-05-12T13:20:40Z',
#   'allowComments': True,
#   'title': 'orci luctus et',
#   'description': 'rhoncus dui vel sem sed sagittis nam congue risus semper porta volutpat quam pede lobortis ligula sit amet eleifend pede libero quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti cras in purus eu magna vulputate luctus cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus vivamus vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent',
#   'tags': 5,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2018-07-09T18:55:10Z',
#   'allowComments': False,
#   'title': 'sed lacus morbi sem',
#   'description': 'porta volutpat quam pede lobortis ligula sit amet eleifend pede libero quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti cras in purus eu magna vulputate luctus cum sociis natoque',
#   'tags': 0,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-03-18T18:16:13Z',
#   'allowComments': False,
#   'title': 'fusce posuere felis sed lacus morbi',
#   'description': 'porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis',
#   'tags': 7,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-07-05T14:12:53Z',
#   'allowComments': False,
#   'title': 'justo aliquam quis turpis eget',
#   'description': 'dictumst etiam faucibus cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at',
#   'tags': 9,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2018-04-30T21:39:50Z',
#   'allowComments': False,
#   'title': 'ultrices aliquet maecenas',
#   'description': 'sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere',
#   'tags': 6,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2016-07-03T04:39:52Z',
#   'allowComments': True,
#   'title': 'lectus pellentesque at nulla suspendisse',
#   'description': 'massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque',
#   'tags': 7,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2018-10-10T03:00:52Z',
#   'allowComments': False,
#   'title': 'magna bibendum imperdiet nullam',
#   'description': 'lorem id ligula suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac',
#   'tags': 7,
#   'Category': 'educational',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2015-09-02T15:00:20Z',
#   'allowComments': True,
#   'title': 'erat volutpat',
#   'description': 'nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac habitasse platea dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum justo nec condimentum neque sapien placerat ante nulla justo aliquam quis turpis eget elit sodales scelerisque mauris sit amet eros suspendisse accumsan tortor quis turpis sed ante vivamus tortor duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis',
#   'tags': 3,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-06-15T00:45:42Z',
#   'allowComments': True,
#   'title': 'luctus',
#   'description': 'ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris',
#   'tags': 8,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2018-08-02T15:22:33Z',
#   'allowComments': False,
#   'title': 'amet cursus',
#   'description': 'massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat',
#   'tags': 3,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2020-05-28T20:43:39Z',
#   'allowComments': True,
#   'title': 'diam vitae quam suspendisse potenti nullam',
#   'description': 'ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam',
#   'tags': 5,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-05-06T07:16:36Z',
#   'allowComments': False,
#   'title': 'justo aliquam quis',
#   'description': 'fusce lacus purus aliquet at feugiat non pretium quis lectus suspendisse potenti in',
#   'tags': 3,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-02-05T11:19:24Z',
#   'allowComments': False,
#   'title': 'primis in faucibus orci',
#   'description': 'proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus',
#   'tags': 3,
#   'Category': 'lifestyle',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2017-02-14T10:09:25Z',
#   'allowComments': False,
#   'title': 'nisi nam ultrices',
#   'description': 'lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in',
#   'tags': 4,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-11-29T07:33:24Z',
#   'allowComments': True,
#   'title': 'sed augue aliquam erat volutpat',
#   'description': 'potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non lectus aliquam sit amet diam in magna bibendum imperdiet nullam orci pede venenatis non sodales sed tincidunt eu felis fusce posuere felis sed lacus morbi sem mauris laoreet ut rhoncus aliquet pulvinar sed nisl nunc rhoncus dui vel sem sed sagittis nam congue risus semper porta volutpat quam pede lobortis ligula sit amet eleifend pede libero quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti',
#   'tags': 10,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2019-10-06T06:08:14Z',
#   'allowComments': False,
#   'title': 'pretium',
#   'description': 'nulla pede ullamcorper augue a suscipit nulla elit ac nulla sed vel enim sit amet nunc viverra dapibus nulla',
#   'tags': 6,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-05-19T18:23:00Z',
#   'allowComments': False,
#   'title': 'diam id ornare imperdiet sapien urna',
#   'description': 'eget tincidunt eget tempus vel pede morbi porttitor lorem id ligula suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis',
#   'tags': 9,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-11-28T06:03:37Z',
#   'allowComments': False,
#   'title': 'pede',
#   'description': 'a feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl ut volutpat sapien arcu sed augue aliquam erat',
#   'tags': 3,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-05-26T03:49:20Z',
#   'allowComments': False,
#   'title': 'amet eros',
#   'description': 'cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget',
#   'tags': 4,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2018-08-07T20:05:11Z',
#   'allowComments': False,
#   'title': 'quis libero nullam',
#   'description': 'odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis',
#   'tags': 10,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-08-06T14:52:59Z',
#   'allowComments': True,
#   'title': 'consequat dui nec',
#   'description': 'faucibus cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis odio donec vitae nisi nam ultrices libero non mattis pulvinar',
#   'tags': 8,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2021-10-05T11:31:20Z',
#   'allowComments': True,
#   'title': 'ac consequat metus sapien',
#   'description': 'purus aliquet at feugiat non pretium quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue luctus tincidunt nulla mollis molestie lorem quisque ut erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam',
#   'tags': 0,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-11-14T05:32:34Z',
#   'allowComments': False,
#   'title': 'ligula suspendisse ornare',
#   'description': 'sed ante vivamus tortor duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor vel est donec odio justo sollicitudin ut suscipit a feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue',
#   'tags': 0,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-02-04T02:11:28Z',
#   'allowComments': True,
#   'title': 'dolor sit amet consectetuer',
#   'description': 'posuere cubilia curae duis faucibus accumsan odio curabitur convallis duis consequat dui nec nisi volutpat eleifend donec ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa',
#   'tags': 6,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2019-04-19T15:39:39Z',
#   'allowComments': True,
#   'title': 'justo nec condimentum neque sapien placerat',
#   'description': 'justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl',
#   'tags': 2,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-06-01T07:45:32Z',
#   'allowComments': True,
#   'title': 'leo pellentesque ultrices mattis',
#   'description': 'tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim',
#   'tags': 7,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-06-24T04:23:00Z',
#   'allowComments': True,
#   'title': 'nisi at nibh',
#   'description': 'feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl ut volutpat sapien arcu sed augue aliquam erat volutpat in congue etiam justo etiam pretium iaculis justo in hac habitasse platea dictumst etiam faucibus cursus urna ut tellus nulla ut erat',
#   'tags': 5,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-11-04T01:46:16Z',
#   'allowComments': True,
#   'title': 'id turpis integer aliquet massa id',
#   'description': 'libero quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti cras in purus eu magna vulputate luctus cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus vivamus vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id',
#   'tags': 0,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2019-01-11T06:17:26Z',
#   'allowComments': False,
#   'title': 'elementum in',
#   'description': 'mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante',
#   'tags': 0,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-12-06T04:59:08Z',
#   'allowComments': False,
#   'title': 'id nulla ultrices aliquet maecenas',
#   'description': 'pellentesque ultrices mattis odio donec vitae nisi nam ultrices libero non mattis pulvinar nulla pede ullamcorper augue a suscipit nulla elit ac nulla sed vel enim sit amet nunc viverra dapibus nulla suscipit ligula in lacus curabitur at ipsum ac tellus semper interdum mauris ullamcorper purus sit amet nulla quisque arcu libero rutrum ac lobortis',
#   'tags': 1,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-07-27T23:27:30Z',
#   'allowComments': False,
#   'title': 'ut',
#   'description': 'non pretium quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue luctus tincidunt nulla mollis molestie lorem quisque ut erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam augue quam sollicitudin vitae consectetuer eget rutrum at lorem integer tincidunt ante vel ipsum praesent blandit lacinia erat vestibulum sed magna at nunc commodo placerat praesent blandit nam nulla',
#   'tags': 8,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-01-28T19:37:20Z',
#   'allowComments': True,
#   'title': 'erat curabitur gravida nisi at nibh',
#   'description': 'libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam',
#   'tags': 1,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-04-20T11:53:36Z',
#   'allowComments': True,
#   'title': 'tincidunt eget tempus vel pede morbi',
#   'description': 'orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non',
#   'tags': 3,
#   'Category': 'lifestyle',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2020-10-04T05:20:27Z',
#   'allowComments': False,
#   'title': 'ac consequat metus',
#   'description': 'cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis odio',
#   'tags': 10,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-06-17T11:01:35Z',
#   'allowComments': False,
#   'title': 'vulputate elementum nullam',
#   'description': 'ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non lectus aliquam sit amet diam in magna bibendum imperdiet nullam orci pede venenatis non sodales sed tincidunt eu felis fusce posuere felis sed lacus morbi sem mauris laoreet ut rhoncus aliquet pulvinar sed nisl nunc rhoncus dui vel sem sed sagittis nam congue risus semper porta volutpat quam pede lobortis ligula sit amet eleifend pede libero quis orci nullam molestie nibh in lectus pellentesque at',
#   'tags': 2,
#   'Category': 'sports',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2021-09-11T23:02:53Z',
#   'allowComments': True,
#   'title': 'nulla nisl nunc nisl duis',
#   'description': 'a feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl ut volutpat sapien',
#   'tags': 7,
#   'Category': 'educational',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2020-04-07T14:15:01Z',
#   'allowComments': True,
#   'title': 'dapibus augue',
#   'description': 'nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu',
#   'tags': 7,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-05-12T20:11:48Z',
#   'allowComments': True,
#   'title': 'donec vitae nisi nam ultrices',
#   'description': 'id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor vel est donec odio justo sollicitudin ut suscipit a feugiat et eros vestibulum ac',
#   'tags': 8,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2019-04-17T22:47:36Z',
#   'allowComments': False,
#   'title': 'tortor duis mattis egestas',
#   'description': 'aliquet pulvinar sed nisl nunc rhoncus dui vel sem sed sagittis nam congue risus semper porta',
#   'tags': 7,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-09-04T18:31:12Z',
#   'allowComments': False,
#   'title': 'dis parturient montes nascetur ridiculus',
#   'description': 'mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac habitasse platea dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum justo nec condimentum neque sapien placerat ante nulla justo aliquam quis turpis eget elit sodales scelerisque mauris sit amet eros suspendisse accumsan tortor quis turpis sed ante vivamus tortor duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor vel est donec',
#   'tags': 3,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2019-05-20T05:20:23Z',
#   'allowComments': True,
#   'title': 'quisque porta volutpat erat quisque erat',
#   'description': 'dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum',
#   'tags': 6,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-02-23T13:44:04Z',
#   'allowComments': True,
#   'title': 'augue vestibulum ante ipsum',
#   'description': 'leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras',
#   'tags': 3,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-04-07T17:44:36Z',
#   'allowComments': True,
#   'title': 'in',
#   'description': 'tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum',
#   'tags': 6,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-07-09T12:50:19Z',
#   'allowComments': False,
#   'title': 'ante ipsum primis',
#   'description': 'ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices',
#   'tags': 10,
#   'Category': 'sports',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2019-12-10T11:31:14Z',
#   'allowComments': True,
#   'title': 'mauris sit amet eros suspendisse accumsan',
#   'description': 'vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non quam nec dui luctus rutrum nulla tellus in sagittis dui vel nisl duis ac nibh fusce lacus purus aliquet at feugiat non pretium quis lectus suspendisse potenti',
#   'tags': 4,
#   'Category': 'educational',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-05-09T03:41:21Z',
#   'allowComments': False,
#   'title': 'dapibus nulla suscipit ligula',
#   'description': 'vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet',
#   'tags': 5,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-06-27T11:30:15Z',
#   'allowComments': False,
#   'title': 'duis faucibus accumsan odio curabitur',
#   'description': 'consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non',
#   'tags': 2,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-08-15T08:57:13Z',
#   'allowComments': True,
#   'title': 'aenean fermentum donec ut mauris',
#   'description': 'malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod',
#   'tags': 3,
#   'Category': 'educational',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-08-08T02:15:10Z',
#   'allowComments': True,
#   'title': 'lacus curabitur',
#   'description': 'sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non lectus aliquam',
#   'tags': 5,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2018-09-25T17:44:49Z',
#   'allowComments': False,
#   'title': 'massa id lobortis convallis tortor risus',
#   'description': 'praesent lectus vestibulum quam sapien varius ut blandit non interdum in ante vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae duis faucibus accumsan odio curabitur convallis duis consequat dui nec nisi volutpat eleifend donec ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio',
#   'tags': 9,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2019-04-18T12:37:35Z',
#   'allowComments': False,
#   'title': 'interdum mauris ullamcorper',
#   'description': 'quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue',
#   'tags': 3,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-11-01T05:35:41Z',
#   'allowComments': False,
#   'title': 'rutrum at lorem integer tincidunt',
#   'description': 'in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque',
#   'tags': 4,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2021-01-08T13:53:21Z',
#   'allowComments': False,
#   'title': 'cum sociis natoque penatibus et magnis',
#   'description': 'nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo',
#   'tags': 5,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2021-06-21T08:40:47Z',
#   'allowComments': True,
#   'title': 'nullam',
#   'description': 'id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam non mauris morbi non lectus aliquam sit amet diam in magna bibendum imperdiet nullam orci pede venenatis non sodales sed tincidunt',
#   'tags': 5,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-02-20T04:16:31Z',
#   'allowComments': True,
#   'title': 'elementum eu interdum eu tincidunt in',
#   'description': 'imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing',
#   'tags': 6,
#   'Category': 'lifestyle',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2019-04-22T13:57:02Z',
#   'allowComments': False,
#   'title': 'vulputate elementum nullam varius nulla facilisi',
#   'description': 'augue luctus tincidunt nulla mollis molestie lorem quisque ut erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam augue quam sollicitudin vitae consectetuer eget rutrum at lorem integer tincidunt ante vel ipsum praesent blandit lacinia erat vestibulum sed magna at nunc commodo placerat praesent blandit nam nulla integer pede justo lacinia eget tincidunt eget tempus vel pede morbi porttitor lorem id ligula suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor',
#   'tags': 8,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-08-30T08:27:36Z',
#   'allowComments': True,
#   'title': 'turpis eget elit sodales scelerisque mauris',
#   'description': 'molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris viverra diam vitae quam suspendisse potenti nullam porttitor lacus at turpis donec posuere metus vitae ipsum aliquam',
#   'tags': 1,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2021-05-04T08:41:17Z',
#   'allowComments': False,
#   'title': 'quam',
#   'description': 'hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula',
#   'tags': 10,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2016-11-15T21:11:15Z',
#   'allowComments': False,
#   'title': 'sociis natoque penatibus',
#   'description': 'euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices',
#   'tags': 3,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2018-06-28T19:14:51Z',
#   'allowComments': True,
#   'title': 'et ultrices posuere',
#   'description': 'vitae consectetuer eget rutrum at lorem integer tincidunt ante vel ipsum praesent blandit lacinia erat vestibulum sed magna at nunc commodo placerat praesent blandit nam nulla integer pede justo lacinia eget tincidunt eget tempus vel pede morbi porttitor lorem id ligula suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac habitasse platea dictumst morbi',
#   'tags': 4,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-06-12T01:53:39Z',
#   'allowComments': True,
#   'title': 'mi integer ac neque duis bibendum',
#   'description': 'proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae',
#   'tags': 3,
#   'Category': 'arts',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2019-01-02T02:40:33Z',
#   'allowComments': False,
#   'title': 'eget eros elementum pellentesque quisque',
#   'description': 'habitasse platea dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum justo nec condimentum neque sapien placerat ante nulla justo aliquam quis turpis eget elit sodales scelerisque mauris sit amet eros suspendisse accumsan tortor quis turpis sed ante vivamus tortor duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et',
#   'tags': 4,
#   'Category': 'lifestyle',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2020-10-06T02:34:06Z',
#   'allowComments': False,
#   'title': 'eget nunc donec quis orci eget',
#   'description': 'erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam augue quam sollicitudin vitae consectetuer eget rutrum at lorem integer tincidunt ante vel ipsum praesent blandit lacinia erat vestibulum sed magna at nunc commodo placerat praesent blandit nam nulla integer pede justo lacinia eget tincidunt eget tempus vel pede morbi porttitor lorem id ligula suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac habitasse platea dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum justo nec',
#   'tags': 10,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2016-05-15T02:21:00Z',
#   'allowComments': True,
#   'title': 'nulla nisl nunc nisl',
#   'description': 'elit proin risus praesent lectus vestibulum quam sapien varius ut blandit non interdum in ante vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae duis faucibus accumsan odio curabitur convallis duis consequat dui nec nisi volutpat eleifend donec ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas',
#   'tags': 3,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-07-27T07:15:52Z',
#   'allowComments': True,
#   'title': 'pharetra magna ac consequat metus',
#   'description': 'aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non quam nec dui luctus rutrum nulla tellus in sagittis dui vel nisl duis ac nibh fusce lacus',
#   'tags': 9,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2019-11-13T20:44:26Z',
#   'allowComments': False,
#   'title': 'porta volutpat erat quisque erat',
#   'description': 'vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit',
#   'tags': 0,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2018-03-10T12:17:54Z',
#   'allowComments': False,
#   'title': 'consequat in consequat',
#   'description': 'facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis odio donec vitae nisi nam ultrices libero non mattis pulvinar nulla pede ullamcorper augue a suscipit nulla elit ac nulla sed vel enim sit',
#   'tags': 1,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2018-08-29T13:29:08Z',
#   'allowComments': False,
#   'title': 'duis bibendum morbi non quam nec',
#   'description': 'id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing',
#   'tags': 8,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2018-05-16T01:53:50Z',
#   'allowComments': True,
#   'title': 'curae donec',
#   'description': 'aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et',
#   'tags': 9,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-09-30T20:29:38Z',
#   'allowComments': True,
#   'title': 'nisl nunc rhoncus dui',
#   'description': 'est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere',
#   'tags': 3,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-04-12T08:17:41Z',
#   'allowComments': True,
#   'title': 'velit vivamus vel nulla',
#   'description': 'ante vel ipsum praesent blandit lacinia erat vestibulum sed magna at nunc commodo placerat praesent blandit nam nulla integer pede justo lacinia eget tincidunt eget tempus vel pede morbi porttitor lorem id ligula suspendisse ornare consequat lectus in est risus auctor',
#   'tags': 3,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2016-06-29T21:03:20Z',
#   'allowComments': False,
#   'title': 'nisl duis ac',
#   'description': 'suspendisse ornare consequat lectus in est risus auctor sed tristique in tempus sit amet sem',
#   'tags': 10,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-02-01T08:47:46Z',
#   'allowComments': False,
#   'title': 'ultrices posuere cubilia curae duis faucibus',
#   'description': 'diam erat fermentum justo nec condimentum neque sapien placerat ante nulla justo aliquam quis turpis eget elit sodales scelerisque mauris sit amet eros suspendisse accumsan tortor quis turpis sed ante vivamus tortor duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia',
#   'tags': 5,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2018-10-11T16:38:46Z',
#   'allowComments': True,
#   'title': 'in',
#   'description': 'cubilia curae duis faucibus accumsan odio curabitur convallis duis consequat dui nec nisi volutpat eleifend donec ut dolor morbi vel lectus in quam fringilla rhoncus mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh',
#   'tags': 7,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-09-19T15:14:11Z',
#   'allowComments': False,
#   'title': 'turpis sed',
#   'description': 'ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae',
#   'tags': 2,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2018-08-22T11:06:13Z',
#   'allowComments': True,
#   'title': 'suscipit nulla elit ac nulla sed',
#   'description': 'eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed',
#   'tags': 8,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2019-02-08T20:58:30Z',
#   'allowComments': True,
#   'title': 'et eros vestibulum ac est',
#   'description': 'justo etiam pretium iaculis justo in hac habitasse platea dictumst etiam faucibus cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed',
#   'tags': 1,
#   'Category': 'sports',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2021-07-18T16:33:44Z',
#   'allowComments': True,
#   'title': 'orci pede venenatis non',
# ...
#   'tags': 7,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2017-01-26T20:21:11Z',
#   'allowComments': True,
#   'title': 'habitasse platea dictumst morbi vestibulum',
#   'description': 'primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor vel est donec odio justo sollicitudin ut suscipit a feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl ut volutpat sapien arcu sed augue aliquam erat volutpat in congue etiam justo etiam pretium iaculis justo in hac habitasse platea dictumst etiam faucibus cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros',
#   'tags': 7,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2018-02-01T16:05:47Z',
#   'allowComments': True,
#   'title': 'nulla sed vel',
#   'description': 'duis mattis egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor vel est donec odio justo sollicitudin ut suscipit a feugiat et eros vestibulum ac est lacinia nisi venenatis tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl',
#   'tags': 4,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-04-20T18:52:03Z',
#   'allowComments': False,
#   'title': 'tortor sollicitudin mi sit',
#   'description': 'duis ac nibh fusce lacus purus aliquet at feugiat non pretium quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue luctus tincidunt nulla mollis molestie lorem quisque ut erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam augue quam sollicitudin vitae consectetuer eget rutrum at lorem integer tincidunt ante vel ipsum praesent blandit lacinia',
#   'tags': 9,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2017-02-16T23:24:38Z',
#   'allowComments': True,
#   'title': 'convallis nulla neque libero',
#   'description': 'tristique fusce congue diam id ornare imperdiet sapien urna pretium nisl ut volutpat sapien arcu',
#   'tags': 5,
#   'Category': 'movies',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2015-12-20T22:32:09Z',
#   'allowComments': True,
#   'title': 'consequat metus sapien ut nunc vestibulum',
#   'description': 'penatibus et magnis dis parturient montes nascetur ridiculus mus vivamus vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id',
#   'tags': 2,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2017-07-17T06:38:32Z',
#   'allowComments': True,
#   'title': 'cum sociis natoque penatibus',
#   'description': 'in purus eu magna vulputate luctus cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus vivamus vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut',
#   'tags': 6,
#   'Category': 'fashion',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-11-04T10:30:23Z',
#   'allowComments': True,
#   'title': 'nec nisi vulputate nonummy maecenas tincidunt',
#   'description': 'mauris enim leo rhoncus sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a',
#   'tags': 6,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2018-09-01T16:00:07Z',
#   'allowComments': False,
#   'title': 'at velit',
#   'description': 'egestas metus aenean fermentum donec ut mauris eget massa tempor convallis nulla neque libero convallis eget eleifend luctus ultricies eu nibh quisque id justo sit amet sapien dignissim vestibulum vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae nulla dapibus dolor',
#   'tags': 1,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-04-26T03:34:48Z',
#   'allowComments': False,
#   'title': 'dis parturient montes nascetur ridiculus mus',
#   'description': 'rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla sed accumsan felis ut at dolor quis odio consequat varius integer ac leo pellentesque ultrices mattis odio donec vitae nisi nam ultrices libero non mattis pulvinar nulla pede ullamcorper augue',
#   'tags': 4,
#   'Category': 'sports',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2019-06-14T14:35:16Z',
#   'allowComments': True,
#   'title': 'sagittis nam congue',
#   'description': 'placerat praesent blandit nam nulla integer pede justo lacinia eget tincidunt eget tempus vel pede morbi',
#   'tags': 6,
#   'Category': 'arts',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2016-02-27T19:24:08Z',
#   'allowComments': True,
#   'title': 'pede ullamcorper augue a suscipit nulla',
#   'description': 'orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi',
#   'tags': 3,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2018-06-17T15:07:29Z',
#   'allowComments': False,
#   'title': 'adipiscing elit proin risus',
#   'description': 'velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus',
#   'tags': 9,
#   'Category': 'sports',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2019-01-18T14:34:00Z',
#   'allowComments': True,
#   'title': 'et eros vestibulum ac est',
#   'description': 'vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing',
#   'tags': 7,
#   'Category': 'educational',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2020-08-14T18:21:50Z',
#   'allowComments': True,
#   'title': 'et',
#   'description': 'fusce consequat nulla nisl nunc nisl duis bibendum felis sed interdum venenatis turpis enim blandit mi in porttitor pede justo eu massa donec dapibus duis at velit eu est congue elementum in hac habitasse platea dictumst morbi vestibulum velit id pretium iaculis diam erat fermentum justo nec condimentum neque sapien placerat ante nulla justo aliquam quis turpis eget elit sodales scelerisque mauris sit amet eros suspendisse accumsan tortor quis turpis',
#   'tags': 3,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2019-02-11T22:49:19Z',
#   'allowComments': True,
#   'title': 'quisque porta',
#   'description': 'pede libero quis orci nullam molestie nibh in lectus pellentesque at nulla suspendisse potenti cras in purus eu magna vulputate luctus cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus vivamus vestibulum sagittis sapien cum sociis natoque penatibus et magnis dis parturient montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa',
#   'tags': 8,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-04-01T04:18:59Z',
#   'allowComments': True,
#   'title': 'cursus urna ut',
#   'description': 'sed vestibulum sit amet cursus id turpis integer aliquet massa id lobortis convallis tortor risus dapibus augue vel accumsan tellus nisi eu orci mauris lacinia sapien quis libero nullam sit amet turpis elementum ligula vehicula consequat morbi a ipsum integer a nibh in quis justo maecenas rhoncus aliquam lacus morbi quis tortor id nulla ultrices aliquet maecenas leo odio condimentum id luctus nec molestie sed justo pellentesque viverra pede ac diam cras pellentesque volutpat dui maecenas tristique est et tempus semper est quam pharetra magna ac consequat metus sapien ut nunc vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae mauris',
#   'tags': 10,
#   'Category': 'sports',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2017-10-05T11:37:12Z',
#   'allowComments': True,
#   'title': 'nulla',
#   'description': 'sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu',
#   'tags': 4,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2020-10-16T13:37:57Z',
#   'allowComments': False,
#   'title': 'mi sit',
#   'description': 'montes nascetur ridiculus mus etiam vel augue vestibulum rutrum rutrum neque aenean auctor gravida sem praesent id massa id nisl venenatis lacinia aenean sit amet justo morbi ut odio cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa',
#   'tags': 1,
#   'Category': 'movies',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2020-10-24T13:02:13Z',
#   'allowComments': True,
#   'title': 'ipsum primis in faucibus orci',
#   'description': 'morbi non quam nec dui luctus rutrum nulla tellus in sagittis dui vel nisl duis ac nibh fusce lacus purus aliquet at feugiat non pretium quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue luctus tincidunt nulla mollis molestie lorem quisque',
#   'tags': 2,
#   'Category': 'lifestyle',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2021-08-23T14:05:16Z',
#   'allowComments': False,
#   'title': 'tempor convallis nulla neque libero',
#   'description': 'in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia',
#   'tags': 6,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'public',
#   'creationDate': '2020-08-28T21:40:16Z',
#   'allowComments': False,
#   'title': 'vestibulum',
#   'description': 'in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis',
#   'tags': 4,
#   'Category': 'fashion',
#   'filteredPicture': False},
#  {'status': 'public',
#   'creationDate': '2015-10-30T01:19:18Z',
#   'allowComments': False,
#   'title': 'risus auctor sed tristique in',
#   'description': 'nisl ut volutpat sapien arcu sed augue aliquam erat volutpat in congue etiam justo etiam pretium iaculis justo in hac habitasse platea dictumst etiam faucibus cursus urna ut tellus nulla ut erat id mauris vulputate elementum nullam varius nulla facilisi cras non velit nec nisi vulputate nonummy maecenas tincidunt lacus at velit vivamus vel nulla eget eros elementum pellentesque quisque porta volutpat erat quisque erat eros viverra eget congue eget semper rutrum nulla nunc purus phasellus in felis donec semper sapien a libero nam dui proin leo odio porttitor id consequat in consequat ut nulla',
#   'tags': 2,
#   'Category': 'politics',
#   'filteredPicture': False},
#  {'status': 'private',
#   'creationDate': '2021-08-01T01:15:51Z',
#   'allowComments': False,
#   'title': 'curae mauris viverra diam',
#   'description': 'orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non quam nec dui luctus rutrum nulla tellus in sagittis dui vel nisl duis ac nibh fusce lacus purus aliquet at feugiat non pretium quis lectus suspendisse potenti in eleifend quam a odio in hac habitasse platea dictumst maecenas ut massa quis augue luctus tincidunt nulla mollis molestie lorem quisque ut erat curabitur gravida nisi at nibh in hac habitasse platea dictumst aliquam augue quam sollicitudin vitae consectetuer eget rutrum at lorem integer tincidunt ante',
#   'tags': 6,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2018-05-28T08:00:02Z',
#   'allowComments': True,
#   'title': 'cursus vestibulum proin eu',
#   'description': 'cras mi pede malesuada in imperdiet et commodo vulputate justo in blandit ultrices enim lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at vulputate vitae nisl aenean lectus pellentesque eget nunc donec quis orci eget orci vehicula condimentum curabitur in libero ut massa volutpat convallis morbi odio odio elementum eu interdum eu tincidunt in leo maecenas pulvinar lobortis est phasellus sit amet erat nulla tempus vivamus in felis eu sapien cursus vestibulum proin eu mi nulla ac enim',
#   'tags': 1,
#   'Category': 'politics',
#   'filteredPicture': True},
#  {'status': 'private',
#   'creationDate': '2016-03-31T01:35:11Z',
#   'allowComments': False,
#   'title': 'vestibulum ante',
#   'description': 'lorem ipsum dolor sit amet consectetuer adipiscing elit proin interdum mauris non ligula pellentesque ultrices phasellus id sapien in sapien iaculis congue vivamus metus arcu adipiscing molestie hendrerit at',
#   'tags': 7,
#   'Category': 'movies',
#   'filteredPicture': False},
#  ...]

# %%
# Insere o conteúdo do arquivo json na coleção chamada posts. Cada item do arquivo será um documento.
posts.insert_many(file_data, ordered = False, bypass_document_validation = True)

# %%
# Retorna 1 item
posts.find_one()
# Out:
# {'_id': ObjectId('64e6067ea0eabf618be00941'),
#  'status': 'public',
#  'creationDate': '2017-07-17T20:05:49Z',
#  'allowComments': True,
#  'title': 'ligula nec sem duis aliquam',
#  'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#  'tags': 1,
#  'Category': 'lifestyle',
#  'filteredPicture': False}

# %%
# Extrai o número de documentos (posts)
n = posts.estimated_document_count()

# %%
n
# Out:
# 2000

# %% [markdown]
# ## Pré-Processamento e Análise

# %% [markdown]
# > Agregação para calcular o número de posts em cada categoria.

# %%
# Agregação para calcular o número de posts em cada categoria
posts_cat = posts.aggregate([{"$group": {"_id": "$Category", "count": {"$sum": 1}}},
                             {"$sort": {"_id.Category": 1, "count": -1}}])

# %%
print(posts_cat)
# Out:
# <pymongo.command_cursor.CommandCursor object at 0x1281c0bb0>

# %%
# Converte o resultado da agregação em um dataframe
pc_df = pd.DataFrame(list(posts_cat))

# %%
pc_df.head()
# Out:
#          _id  count
# 0       arts    311
# 1    fashion    300
# 2  lifestyle    294
# 3     movies    289
# 4   politics    274

# %%
# Listas os ids (categorias)
list(pc_df['_id'])
# Out:
# ['arts', 'fashion', 'lifestyle', 'movies', 'politics', 'educational', 'sports']

# %%
# Plot
pc_df.plot.pie(y = 'count',
               labels = pc_df['_id'],
               autopct = '%1.1f%%',
               startangle = 15, 
               shadow = True,
               legend = False)
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# > Número de posts públicos e privados da categoria **politics**.

# %%
# Número de posts públicos e privados da categoria politics
pol_sta = posts.aggregate([{"$match": {"Category": "politics"}}, #match é o filtro
                           {"$group": {"_id": "$status", "count": {"$sum": 1}}}]) #agrupando pelo status, fazendo count e soma

# %%
ps_df = pd.DataFrame(list(pol_sta))

# %%
ps_df
# Out:
#        _id  count
# 0  private    148
# 1   public    126

# %%
# Plot
ps_df.plot.bar(x = '_id',
               y = 'count',
               title = "Número de Posts Públicos e Privados")
# Out:
# <AxesSubplot:title={'center':'Número de Posts Públicos e Privados'}, xlabel='_id'>

# %% [markdown]
# > Qual ano teve o maior número de posts?

# %%
# Retorna 1 item
posts.find_one()
# Out:
# {'_id': ObjectId('64e6067ea0eabf618be00941'),
#  'status': 'public',
#  'creationDate': '2017-07-17T20:05:49Z',
#  'allowComments': True,
#  'title': 'ligula nec sem duis aliquam',
#  'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#  'tags': 1,
#  'Category': 'lifestyle',
#  'filteredPicture': False}

# %%
# Update many (cria duas noovas variáveis para cada documento)
datalake.posts.update_many({}, {'$set': {"hour": 0}}); # set cria uma nova coluna, que chamo de hour preenchendo com 0. O {} é porque nao quero nenhum filtro
datalake.posts.update_many({}, {'$set': {"year": 0}}); # aqui o nome da coluna é year

# %%
# Retorna 1 item
posts.find_one()
# Out:
# {'_id': ObjectId('64e6067ea0eabf618be00941'),
#  'status': 'public',
#  'creationDate': '2017-07-17T20:05:49Z',
#  'allowComments': True,
#  'title': 'ligula nec sem duis aliquam',
#  'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#  'tags': 1,
#  'Category': 'lifestyle',
#  'filteredPicture': False,
#  'hour': 0,
#  'year': 0}

# %%
# Update one (atualiza as duas variáveis com os valores correspondentes extraídos da coluna de data)
for data in posts.find({}):
    posts.update_one({"_id": data['_id']},
                     {'$set': {'hour' : data['creationDate'].split('T')[1].split(':')[0],
                               'year' : data['creationDate'].split('T')[0].split('-')[0] }})

# %%
# Retorna 1 item
posts.find_one()
# Out:
# {'_id': ObjectId('64e6067ea0eabf618be00941'),
#  'status': 'public',
#  'creationDate': '2017-07-17T20:05:49Z',
#  'allowComments': True,
#  'title': 'ligula nec sem duis aliquam',
#  'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#  'tags': 1,
#  'Category': 'lifestyle',
#  'filteredPicture': False,
#  'hour': '20',
#  'year': '2017'}

# %%
# Agregação
posts_yr = posts.aggregate([{"$group": {"_id": "$year", "count": {"$sum": 1}}},
                            {"$sort": {"_id.year": 1, "count": 1}}])

# %%
py_df = pd.DataFrame(list(posts_yr))
py_df
# Out:
#     _id  count
# 0  2015     76
# 1  2016    299
# 2  2019    303
# 3  2017    309
# 4  2021    330
# 5  2020    334
# 6  2018    349

# %%
# Plot
py_df.plot.line(x = '_id',
                y = 'count',
                title = "Número de Posts Por Ano")
# Out:
# <AxesSubplot:title={'center':'Número de Posts Por Ano'}, xlabel='_id'>

# %% [markdown]
# > Qual o horário com maior número de posts?

# %%
# Agregação e ordenação
posts_hr = posts.aggregate([{"$group": {"_id": "$hour", "count": {"$sum": 1}}},
                            {"$sort": {"_id.hour": 1, "count": -1}}])

# %%
for i in range(3):
    print(posts_hr.next())
# Out:
# {'_id': '00', 'count': 103}
# {'_id': '08', 'count': 101}
# {'_id': '02', 'count': 99}

# %% [markdown]
# > Número de posts em hora cheia (terminada por 00) por categoria.

# %%
# Filtro, agregação e ordenação
cat_00 = posts.aggregate([{"$match": {"hour": "00"}},
                          {"$group": {"_id": "$Category", "count": {"$sum": 1}}},
                          {"$sort": {"_id.Category": 1, "count": -1}}])

# %%
c0_df = pd.DataFrame(list(cat_00))

# %%
c0_df.plot.bar(x = '_id', y = 'count', title = "Número de Posts em Hora Cheia")
# Out:
# <AxesSubplot:title={'center':'Número de Posts em Hora Cheia'}, xlabel='_id'>

# %% [markdown]
# > Número de posts que permitem comentários.

# %%
# Count
com = posts.count_documents({'allowComments':True})

# %%
print("Número de Posts Que Permitem Comentários:", com)
# Out:
# Número de Posts Que Permitem Comentários: 964

# %%
print("Número de Posts Que Não Permitem Comentários:", n-com)
# Out:
# Número de Posts Que Não Permitem Comentários: 1036

# %%
# Plot
sns.set_style('darkgrid')
x = ['Commented', 'Uncommented']
y = [com, n-com]
sns.barplot(x, y, palette = 'twilight_r')
plt.title("Número de Posts Com e Sem Comentários")
plt.xlabel("Status")
plt.ylabel("Número de Posts")
# Out:
# Text(0, 0.5, 'Número de Posts')

# %% [markdown]
# > Comprimento (número de palavras) do título dos posts.

# %%
# Retorna 1 item
posts.find_one()
# Out:
# {'_id': ObjectId('64e6067ea0eabf618be00941'),
#  'status': 'public',
#  'creationDate': '2017-07-17T20:05:49Z',
#  'allowComments': True,
#  'title': 'ligula nec sem duis aliquam',
#  'description': 'in felis eu sapien cursus vestibulum proin eu mi nulla ac enim in tempor turpis nec euismod scelerisque quam turpis adipiscing lorem vitae mattis nibh ligula nec sem duis aliquam convallis nunc proin at turpis a pede posuere nonummy integer non velit donec diam neque vestibulum eget vulputate ut ultrices vel augue vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae donec pharetra magna vestibulum aliquet ultrices erat tortor sollicitudin mi sit amet lobortis sapien sapien non mi integer ac neque duis bibendum morbi non',
#  'tags': 1,
#  'Category': 'lifestyle',
#  'filteredPicture': False,
#  'hour': '20',
#  'year': '2017'}

# %%
# Cria uma nova coluna
datalake.posts.update_many({}, {'$set': {"length_of_heading": 0}});

# %%
# Loop para preencher a nova coluna
for data in posts.find({}):
    posts.update_one({"_id": data['_id']},
                     {'$set': {'length_of_heading' : len(data['title'].split(' '))}})

# %%
# Agrupamento e ordenação
len_titles = posts.aggregate([{"$group": {"_id": "$length_of_heading", "count": {"$sum": 1}}},
                              {"$sort": {"_id.length_of_heading": 1, "count": -1}}])

# %%
len_titles

# %%
title_df = pd.DataFrame(list(len_titles))
title_df.head(10)
# Out:
#    _id  count
# 0    3    355
# 1    4    345
# 2    1    343
# 3    5    337
# 4    6    336
# 5    2    284

# %%
# Plot
ax = sns.lineplot(x = '_id', y = 'count', data = title_df, color = 'green')
ax.lines[0].set_linestyle("--")
plt.show()

# %% [markdown]
# > Número de tags por categoria de posts.

# %%
# Agregação
tags = posts.aggregate([{"$group": {"_id": "$tags", "count": {"$sum": 1}}},
                        {"$sort": {"_id.tags": 1, "count": -1}}])

# %%
cat_tags = posts.find({'tags': {'$gt':0}}, {'Category':1})
cat_tags

# %%
# Categorias com posts com maior número de tags, sendo o número de tags maior do que zero
cat_tags = posts.aggregate([{"$match": {"tags": {"$gt":0}}},
                            {"$group": {"_id": "$Category", "count": {"$sum": 1}}},
                            {"$sort": {"_id.tags": 1, "count": -1}}])

# %%
ct_df = pd.DataFrame(list(cat_tags))
ct_df
# Out:
#            _id  count
# 0      fashion    276
# 1         arts    276
# 2       movies    264
# 3    lifestyle    262
# 4     politics    258
# 5  educational    255
# 6       sports    235

# %%
sns.barplot(x = '_id', y = 'count', data = ct_df, palette = 'twilight_r')
# Out:
# <AxesSubplot:xlabel='_id', ylabel='count'>

# %% [markdown]
# > Qual categoria usa mais filtros de fotos/imagens?

# %%
# Filtro, agregação e ordenação
cat_fs = posts.aggregate([{"$match": {"filteredPicture": True}},
                          {"$group":{"_id": "$Category", "count": {"$sum": 1}}},
                          {"$sort": {"_id.tags": 1, "count": -1}}])

# %%
for i in range(7):
    print(cat_fs.next())
# Out:
# {'_id': 'fashion', 'count': 159}
# {'_id': 'movies', 'count': 154}
# {'_id': 'arts', 'count': 146}
# {'_id': 'lifestyle', 'count': 136}
# {'_id': 'educational', 'count': 135}
# {'_id': 'politics', 'count': 131}
# {'_id': 'sports', 'count': 117}

# %% [markdown]
# > Nível Ninja: Qual categoria tem posts (descrição) mais longos (com maior número de palavras), acima de 60 caracteres?

# %%
# Cria a variável
datalake.posts.update_many({}, {'$set': {"length_of_des": 0}});

# %%
# Loop para preencher a variável
for data in posts.find({}):
    posts.update_one({"_id": data['_id']}, {'$set': {'length_of_des': len(data['description'].split(' '))}})

# %%
# Filtro, agregação e ordenação
cat_des = posts.aggregate([{"$match": {"length_of_des": {"$gte":60}}},
                           {"$group":{"_id": "$Category", "count": {"$sum": 1}}},
                           {"$sort": {"_id.tags": 1, "count": -1}}])

# %%
for i in range(7):
    print(cat_des.next())
# Out:
# {'_id': 'arts', 'count': 178}
# {'_id': 'fashion', 'count': 161}
# {'_id': 'movies', 'count': 159}
# {'_id': 'lifestyle', 'count': 156}
# {'_id': 'educational', 'count': 156}
# {'_id': 'politics', 'count': 146}
# {'_id': 'sports', 'count': 130}

# %% [markdown]
# > Nível Ninja das Galáxias: O número de posts (descrição) varia de acordo com a hora do dia? Aumenta ou diminui?

# %%
# Agregação e ordenação por hora e categoria
posts_hr = posts.aggregate([{"$group": {"_id": ["$hour", "$Category"], "count": {"$sum": 1}}},
                            {"$sort": {"_id.hour": 1, "count": -1}}])

# %%
postshr_df = pd.DataFrame(posts_hr)
postshr_df
# Out:
#                    _id  count
# 0           [11, arts]     23
# 1       [08, politics]     21
# 2    [11, educational]     20
# 3      [16, lifestyle]     20
# 4      [02, lifestyle]     19
# ..                 ...    ...
# 163       [13, sports]      5
# 164     [22, politics]      5
# 165       [06, sports]      5
# 166    [11, lifestyle]      4
# 167     [12, politics]      3
#
# [168 rows x 2 columns]

# %%
# Split
split_df = pd.DataFrame(postshr_df ['_id'].to_list(), columns = ['hour', 'category'])
split_df
# Out:
#     hour     category
# 0     11         arts
# 1     08     politics
# 2     11  educational
# 3     16    lifestyle
# 4     02    lifestyle
# ..   ...          ...
# 163   13       sports
# 164   22     politics
# 165   06       sports
# 166   11    lifestyle
# 167   12     politics
#
# [168 rows x 2 columns]

# %%
# Concatenação
df = pd.concat([split_df, postshr_df['count']], axis = 1)
df
# Out:
#     hour     category  count
# 0     11         arts     23
# 1     08     politics     21
# 2     11  educational     20
# 3     16    lifestyle     20
# 4     02    lifestyle     19
# ..   ...          ...    ...
# 163   13       sports      5
# 164   22     politics      5
# 165   06       sports      5
# 166   11    lifestyle      4
# 167   12     politics      3
#
# [168 rows x 3 columns]

# %%
df.head(10)
# Out:
#   hour     category  count
# 0   11         arts     23
# 1   08     politics     21
# 2   11  educational     20
# 3   16    lifestyle     20
# 4   02    lifestyle     19
# 5   00    lifestyle     19
# 6   10      fashion     19
# 7   05         arts     19
# 8   06     politics     18
# 9   02     politics     18

# %%
# Plot
fig, ax = plt.subplots()
for key, grp in df.groupby(['category']):
    ax = grp.plot(ax = ax, kind = 'line', x = 'hour', y = 'count', label = key)

plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# # Fim
